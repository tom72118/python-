# %% [markdown]
# # 資料來源(Date source) :
# # https://github.com/CoreyMSchafer/code_snippets/tree/master/Python/Pandas
# # https://www.youtube.com/playlist?list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS

# %%
import pandas as pd

# %% [markdown]
# # basic attribute and method
#     .shape
#     .info()
#     .set_option("display.max_columns(row)",行數)  #顯示行列數
#     .head()
#     .columns    #所有欄位的名稱
#     .index      #所有列名
#     pd.DataFrame()

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}
simple_df = pd.DataFrame(people)
simple_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df = pd.read_csv("developer_survey_2019/survey_results_public.csv",index_col="Respondent")

# %%
pd.set_option("display.max_columns",85)
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df = pd.read_csv("developer_survey_2019/survey_results_schema.csv",index_col="Column")

# %%
pd.set_option("display.max_row",85)
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %% [markdown]
# # selecting row and columns
#     df[["欄位名"]]   #取整欄
#     .iloc[[第幾列],[第幾欄]]     #by integer location 取值
#     .loc[[列名],["欄名"]]        #by label location 取值
#     .value_counts()             #不同資料分別有幾筆

# %%
df.loc[1:5,"Hobbyist":"Employment"]
# Out:
#            Hobbyist                 OpenSourcer  \
# Respondent
# 1               Yes                       Never
# 2                No     Less than once per year
# 3               Yes                       Never
# 4                No                       Never
# 5               Yes  Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time
# 4                               Employed full-time
# ...

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %% [markdown]
# # 操作index
#     .set_index("欄位名")   #改index
#     .reset_index()         #還原
#     .sort_index()          #排序index

# %%
simple_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
simple_df.set_index("email")
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
schema_df.loc["ConvertedComp","QuestionText"]
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.'

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# # 過濾資料
#     df[過濾條件]
#     .loc[過濾條件]
#     &   #and
#     |   #or
#     .isin()  #判斷是否存在
#     .str.contains("")  #判斷字串是否包含

# %% [markdown]
#     找出名字是 Jane Doe 的 email

# %%
filt = (simple_df["last"] == "Doe")&(simple_df["first"] == "Jane")
filt
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
simple_df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com

# %%
simple_df.loc[filt,["email"]]
# Out:
#                email
# 1  JaneDoe@email.com

# %% [markdown]
#     salary > 70000 且
#     country = USA或India或UK或Germany或Canada 且
#     "LanguageWorkedWith" 裡有Python

# %%
high_salary = (df["ConvertedComp"]>70000)

country_size = ["United States","India","United Kingdom","Germany","Canada"]
country = (df["Country"].isin(country_size))

has_python = (df["LanguageWorkedWith"].str.contains("Python",na = False))
df.loc[high_salary&country&has_python,["Country","LanguageWorkedWith","ConvertedComp"]]
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 22          United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26          United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 32          United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 45          United States                                             Python
# 60          United States  Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# ...                   ...                                                ...
# 88839       United States       HTML/CSS;JavaScript;PHP;Python;SQL;Other(s):
# 88861             Germany              Go;HTML/CSS;JavaScript;PHP;Python;SQL
# 88873              Canada               HTML/CSS;JavaScript;PHP;Python;R;SQL
# 88874       United States                               C++;Python;Scala;SQL
# 88876       United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
#
#             ConvertedComp
# ...

# %% [markdown]
# # Updating Rows and Columns
#
#     df.columns = [x.upper() for x in df.coiums]  #欄名改大寫
#     df.columns = df.columns.str.replace("a","b")  #欄名 把a換成b
#     df.rename(columns = {"舊欄位名字":"新名"})  #改特定欄名
#     .map({"原資料名":"新資料名"})   #更改資料(全部都會動到)
#     .replace({"原資料名":"新資料名"}) #更改資料(符合條件的會動到)

# %%
simple_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %% [markdown]
#     df.columns=["新的欄名"]   #改欄名(需要全改掉)

# %%
simple_df.columns = ["first name","last name","email"]
simple_df
# Out:
#   first name last name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %% [markdown]
#     df.columns = [x.upper() for x in df.coiums]  #欄名改大寫

# %%
simple_df.columns = [x.upper() for x in simple_df.columns]
simple_df
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %% [markdown]
#     df.columns = df.columns.str.replace("a","b")  #欄名 把a換成b

# %%
simple_df.columns = simple_df.columns.str.replace(" ","_")
simple_df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
simple_df.rename(columns={"FIRST_NAME":"first","LAST_NAME":"last"},inplace=True)
simple_df.columns = simple_df.columns.str.lower()
simple_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %% [markdown]
# # 套用給定函式
#     .apply(要用的函式名)
#     .applymap(要用的函式名)   #套用DateFrame裡面所有資料

# %%
simple_df["email"].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

simple_df["email"].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
simple_df["email"].apply(lambda x : x.lower())
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@email.com
# 2          johndoe@email.com
# Name: email, dtype: object

# %%
simple_df.apply(pd.Series.min,axis="columns")
# Out:
# 0    Corey
# 1      Doe
# 2      Doe
# dtype: object

# %%
simple_df.apply(lambda x:x.min(),axis="columns")   #x type is Series
# Out:
# 0    Corey
# 1      Doe
# 2      Doe
# dtype: object

# %%
simple_df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
simple_df.applymap(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john      doe        johndoe@email.com

# %% [markdown]
# # exercise
#     將資料欄位名"ConvertedComp"改成"SalaryUSD"

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.rename(columns={"ConvertedComp":"SalaryUSD"},inplace = True)

# %%
df["SalaryUSD"]
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %% [markdown]
#     將"Hobbyist"的 Yes改成True No改成False

# %%
df["Hobbyist"]
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
hobbyist_bool = df["Hobbyist"].apply(lambda x: True if x =="Yes" else False )
hobbyist_bool
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df["Hobbyist"] = hobbyist_bool
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df["Hobbyist"] = df["Hobbyist"].replace({True:"Yes",False:"No"})
df["Hobbyist"]
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %% [markdown]
# # Add/Remove Rows and Columns From DataFrames
#     .append()   #新增
#     .drop()    #刪除
#     .nlargest()
#     .nsmallest()

# %%
simple_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
simple_df["full_name"] = simple_df["first"]+" "+simple_df["last"]
simple_df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
simple_df = simple_df.drop(columns=["first","last"])

# %%
simple_df
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
simple_df[["first","last"]] = simple_df["full_name"].str.split(" ",expand = True)
simple_df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
simple_df = simple_df.append({"first":"Tony"},ignore_index=True,sort=False)

# %%
simple_df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN

# %% [markdown]
#     刪除"first"=="Tony"的列資料

# %%
simple_df = simple_df.drop(index = (simple_df[simple_df["first"]=="Tony"]).index)

# %%
simple_df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %% [markdown]
# # Sorting Data
#     .sort_values()
#     .sort_index()

# %%
simple_df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
simple_df.sort_values(by=["last","first"],ascending=[True,False],inplace=True)
simple_df
# Out:
#                      email      full_name  first     last
# 2        JohnDoe@email.com       John Doe   John      Doe
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer

# %%
simple_df.sort_index()
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %% [markdown]
#     找出前10多"SalaryUSD"的資料

# %%
df["SalaryUSD"].nlargest(10)
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,"SalaryUSD")
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
# 491         I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 770         I am a developer by profession      Yes
# 789         I am a developer by profession      Yes
# 1232        I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 58                                 Once a month or more often
# 102                                                     Never
# 166                                   Less than once per year
# 436                                   Less than once per year
# ...

# %% [markdown]
# # Grouping and Aggregating - Analyzing and Exploring Your Data
#     .median()    #中位數
#     .describe()   #每欄的數學統計資料
#     .value_counts()  #不同資料分別有幾筆
#     .groupby([""])
#     .get_group("要的組別名") #取組別
#     .agg([""])
#     .sum()  #總和
#     .concat([資料1,資料2])  #將資料和在一起

# %%
df.median()
# Out:
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df["SocialMedia"].value_counts(normalize = True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Papua New Guinea             1
# Chad                         1
# Timor-Leste                  1
# Saint Kitts and Nevis        1
# Brunei Darussalam            1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(["Country"])
type(country_grp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
country_grp.get_group("India")
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
country_grp["SocialMedia"].value_counts().loc["India"]
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp["SalaryUSD"].agg(["median","mean"])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
df.loc[df["Country"] == "India"]["LanguageWorkedWith"]
# Out:
# Respondent
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                           C#;Go;JavaScript;Python;R;SQL
# 15       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                         Assembly;C;C++;C#;HTML/CSS;Java
#                                ...
# 77339                                            Other(s):
# 79795                 Bash/Shell/PowerShell;Python;SQL;VBA
# 83862    Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 84299     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 86012        Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %% [markdown]
#     算各國使用Python的比例

# %%
country_respondents = df["Country"].value_counts()
country_respondents
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Papua New Guinea             1
# Chad                         1
# Timor-Leste                  1
# Saint Kitts and Nevis        1
# Brunei Darussalam            1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python],axis="columns",sort = False)
python_df
# Out:
#                        Country  LanguageWorkedWith
# United States            20949               10083
# India                     9061                3105
# Germany                   5866                2451
# United Kingdom            5737                2384
# Canada                    3395                1558
# ...                        ...                 ...
# Papua New Guinea             1                   0
# Chad                         1                   0
# Timor-Leste                  1                   1
# Saint Kitts and Nevis        1                   0
# Brunei Darussalam            1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={"Country":"num respondents","LanguageWorkedWith":"num knowPython"},inplace=True)

# %%
python_df
# Out:
#                        num respondents  num knowPython
# United States                    20949           10083
# India                             9061            3105
# Germany                           5866            2451
# United Kingdom                    5737            2384
# Canada                            3395            1558
# ...                                ...             ...
# Papua New Guinea                     1               0
# Chad                                 1               0
# Timor-Leste                          1               1
# Saint Kitts and Nevis                1               0
# Brunei Darussalam                    1               0
#
# [179 rows x 2 columns]

# %%
python_df["pct knowsPyth"] = (python_df["num knowPython"]/python_df["num respondents"]*100)

# %%
python_df
# Out:
#                        num respondents  num knowPython  pct knowsPyth
# United States                    20949           10083      48.131176
# India                             9061            3105      34.267741
# Germany                           5866            2451      41.783157
# United Kingdom                    5737            2384      41.554820
# Canada                            3395            1558      45.891016
# ...                                ...             ...            ...
# Papua New Guinea                     1               0       0.000000
# Chad                                 1               0       0.000000
# Timor-Leste                          1               1     100.000000
# Saint Kitts and Nevis                1               0       0.000000
# Brunei Darussalam                    1               0       0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by="pct knowsPyth",ascending=False,inplace=True)
python_df
# Out:
#                                   num respondents  num knowPython  \
# Sao Tome and Principe                           1               1
# Niger                                           1               1
# Dominica                                        1               1
# Timor-Leste                                     1               1
# Turkmenistan                                    7               6
# ...                                           ...             ...
# Lao People's Democratic Republic                3               0
# Djibouti                                        2               0
# Cape Verde                                      3               0
# Malawi                                          2               0
# Brunei Darussalam                               1               0
#
#                                   pct knowsPyth
# Sao Tome and Principe                100.000000
# Niger                                100.000000
# ...

# %% [markdown]
# # Cleaning Data - Casting Datatypes and Handling Missing Values
#     .dropna()   #除去有"NaN" None的整列資料
#     .dropa(axis = "index",how="any"("all"),subset=["email"]) #除去"email"欄位有"NaN" None的整列資料
#     .replace("a","b")  #將資料內容a換成b
#     .isna() #判斷是否為na
#     .fillna("")  #將na內容改成自訂內容
#     .astype()  #轉換資料型態
#     .unique()  #列出所有不同資料

# %%
na_vale = ["Na","Missing"]
df = pd.read_csv("developer_survey_2019/survey_results_public.csv",index_col="Respondent",na_values=na_vale)

# %% [markdown]
#     計算YearsCode欄位資料的平均

# %%
schema_df.loc["YearsCode","QuestionText"]
# Out:
# 'Including any education, how many years have you been coding?'

# %%
df["YearsCode"].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df["YearsCode"].replace('Less than 1 year',0,inplace=True)

# %%
df["YearsCode"].replace('More than 50 years',51,inplace=True)

# %%
df["YearsCode"] = df["YearsCode"].astype(float)

# %%
df["YearsCode"].mean()
# Out:
# 11.662114216834588

# %% [markdown]
# # Working with Dates and Time Series Data
#     .to_datetime(df10["Date"],format="%Y-%m-%d %I-%p")  #改成日期時間的格式
#     .dt.day_name()  #整欄的星期
#     .resample("")  #以""為基準分資料

# %%
df10 = pd.read_csv("https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Pandas/10-Datetime-Timeseries/ETH_1h.csv")
df10.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df10.loc[0,"Date"].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-1f67be0d63b3> in <module>
# ----> 1 df10.loc[0,"Date"].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df10["Date"] = pd.to_datetime(df10["Date"],format="%Y-%m-%d %I-%p")

# %%
df10["Date"]
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df10.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
df10["Date"].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df10["DayOfWeek"] = df10["Date"].dt.day_name()

# %%
df10
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %% [markdown]
#     抓出2019的資料

# %%
df10.loc[ (df10["Date"]>=pd.to_datetime("2019")) & (df10["Date"]<"2020")]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %% [markdown]
#     將Date變成index

# %%
df10.set_index(["Date"],inplace=True)

# %%
df10
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df10.loc["2019"]
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
df10.loc["2020-01":"2020-02",["Close"]].mean()
# Out:
# Close    195.16559
# dtype: float64

# %%
df10["2020-01-01"]["High"].max()
# Out:
# 132.68

# %% [markdown]
#     每天的最大值

# %%
highs = df10["High"].resample("D").max()

# %%
highs["2020-01-01"]
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()

# %% [markdown]
#     每欄位每周的平均值

# %%
df10.resample("W").mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %% [markdown]
#     每周 平均價 最高 最低 總量

# %%
df10.resample("W").agg({"Close":"mean","High":"max","Low":"min","Volume":"sum"})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]
